# %%
str1 = """{"data":{"extend":{"id":"animals-extend","trainParameters":{"splitRate":0.5,"seed":5},"trainStatistics":{"id":"animals-extend-train","phraseCount":4,"statsOverAll":{"id":"animals-extend-train-OverAll","tag":"OverAll","expectedCount":8,"observedCount":8,"truePositives":8,"falsePositives":0,"falseNegatives":0,"precision":1,"recall":1,"f1Score":1}},"testStatistics":{"id":"animals-extend-test","phraseCount":4,"statsOverAll":{"id":"animals-extend-test-OverAll","tag":"OverAll","expectedCount":8,"observedCount":8,"truePositives":8,"falsePositives":0,"falseNegatives":0,"precision":1,"recall":1,"f1Score":1},"statsPerEntity":[{"id":"animals-extend-test-Animal","tag":"Animal","expectedCount":4,"observedCount":4,"truePositives":4,"falsePositives":0,"falseNegatives":0,"precision":1,"recall":1,"f1Score":1},{"id":"animals-extend-test-Sound","tag":"Sound","expectedCount":4,"observedCount":4,"truePositives":4,"falsePositives":0,"falseNegatives":0,"precision":1,"recall":1,"f1Score":1}]},"labeledText":{"id":"animals","author":"wiki","sources":[{"id":"The cat says: meow-meow.","xText":"The <Animal>cat</Animal> says: <Sound>meow-meow</Sound>.","entityMentions":[{"tag":"Animal","token":"cat","span":3,"offset":4},{"tag":"Sound","token":"meow-meow","span":9,"offset":14}]},{"id":"The sheep says: baa-baa.","xText":"The <Animal>sheep</Animal> says: <Sound>baa-baa</Sound>.","entityMentions":[{"tag":"Animal","token":"sheep","span":5,"offset":4},{"tag":"Sound","token":"baa-baa","span":7,"offset":16}]},{"id":"The horse says: neigh-neigh.","xText":"The <Animal>horse</Animal> says: <Sound>neigh-neigh</Sound>.","entityMentions":[{"tag":"Animal","token":"horse","span":5,"offset":4},{"tag":"Sound","token":"neigh-neigh","span":11,"offset":16}]},{"id":"The dog says: woof-woof.","xText":"The <Animal>dog</Animal> says: <Sound>woof-woof</Sound>.","entityMentions":[{"tag":"Animal","token":"dog","span":3,"offset":4},{"tag":"Sound","token":"woof-woof","span":9,"offset":14}]},{"id":"The sparrow says: cheep-cheep.","xText":"The <Animal>sparrow</Animal> says: <Sound>cheep-cheep</Sound>.","entityMentions":[{"tag":"Animal","token":"sparrow","span":7,"offset":4},{"tag":"Sound","token":"cheep-cheep","span":11,"offset":18}]},{"id":"The rooster says: cock-a-doodle-doo.","xText":"The <Animal>rooster</Animal> says: <Sound>cock-a-doodle-doo</Sound>.","entityMentions":[{"tag":"Animal","token":"rooster","span":7,"offset":4},{"tag":"Sound","token":"cock-a-doodle-doo","span":17,"offset":18}]},{"id":"The hen says: cluck-cluck.","xText":"The <Animal>hen</Animal> says: <Sound>cluck-cluck</Sound>.","entityMentions":[{"tag":"Animal","token":"hen","span":3,"offset":4},{"tag":"Sound","token":"cluck-cluck","span":11,"offset":14}]},{"id":"The goose says: hhonk-honk.","xText":"The <Animal>goose</Animal> says: <Sound>hhonk-honk</Sound>.","entityMentions":[{"tag":"Animal","token":"goose","span":5,"offset":4},{"tag":"Sound","token":"hhonk-honk","span":10,"offset":16}]},{"id":"The turkey says: gobble-gobble.","xText":"The <Animal>turkey</Animal> says: <Sound>gobble-gobble</Sound>.","entityMentions":[{"tag":"Animal","token":"turkey","span":6,"offset":4},{"tag":"Sound","token":"gobble-gobble","span":13,"offset":17}]},{"id":"The goat says: maa-maa.","xText":"The <Animal>goat</Animal> says: <Sound>maa-maa</Sound>.","entityMentions":[{"tag":"Animal","token":"goat","span":4,"offset":4},{"tag":"Sound","token":"maa-maa","span":7,"offset":15}]},{"id":"The cow says: moo-moo.","xText":"The <Animal>cow</Animal> says: <Sound>moo-moo</Sound>.","entityMentions":[{"tag":"Animal","token":"cow","span":3,"offset":4},{"tag":"Sound","token":"moo-moo","span":7,"offset":14}]},{"id":"The donkey says: hee-haw.","xText":"The <Animal>donkey</Animal> says: <Sound>hee-haw</Sound>.","entityMentions":[{"tag":"Animal","token":"donkey","span":6,"offset":4},{"tag":"Sound","token":"hee-haw","span":7,"offset":17}]},{"id":"The pig says: oink-oink.","xText":"The <Animal>pig</Animal> says: <Sound>oink-oink</Sound>.","entityMentions":[{"tag":"Animal","token":"pig","span":3,"offset":4},{"tag":"Sound","token":"oink-oink","span":9,"offset":14}]},{"id":"The mouse says: squeak-squeak.","xText":"The <Animal>mouse</Animal> says: <Sound>squeak-squeak</Sound>.","entityMentions":[{"tag":"Animal","token":"mouse","span":5,"offset":4},{"tag":"Sound","token":"squeak-squeak","span":13,"offset":16}]},{"id":"The cuckoo says: cuckoo.","xText":"The <Animal>cuckoo</Animal> says: <Sound>cuckoo</Sound>.","entityMentions":[{"tag":"Animal","token":"cuckoo","span":6,"offset":4},{"tag":"Sound","token":"cuckoo","span":6,"offset":17}]},{"id":"The frog says: ribbit-ribbit.","xText":"The <Animal>frog</Animal> says: <Sound>ribbit-ribbit</Sound>.","entityMentions":[{"tag":"Animal","token":"frog","span":4,"offset":4},{"tag":"Sound","token":"ribbit-ribbit","span":13,"offset":15}]},{"id":"The duck says: quack-quack.","xText":"The <Animal>duck</Animal> says: <Sound>quack-quack</Sound>.","entityMentions":[{"tag":"Animal","token":"duck","span":4,"offset":4},{"tag":"Sound","token":"quack-quack","span":11,"offset":15}]},{"id":"The pig says: oink-oink.","xText":"The <Animal>pig</Animal> says: <Sound>oink-oink</Sound>.","entityMentions":[{"tag":"Animal","token":"pig","span":3,"offset":4},{"tag":"Sound","token":"oink-oink","span":9,"offset":14}]},{"id":"The wolf says: owooooo.","xText":"The <Animal>wolf</Animal> says: <Sound>owooooo</Sound>.","entityMentions":[{"tag":"Animal","token":"wolf","span":4,"offset":4},{"tag":"Sound","token":"owooooo","span":7,"offset":15}]},{"id":"The crow says: caw-caw.","xText":"The <Animal>crow</Animal> says: <Sound>caw-caw</Sound>.","entityMentions":[{"tag":"Animal","token":"crow","span":4,"offset":4},{"tag":"Sound","token":"caw-caw","span":7,"offset":15}]}]}}}}"""
str2 = """{"data":{"extend":{"id":"animals-extend","trainParameters":{"splitRate":0.5,"seed":5},"trainStatistics":{"id":"animals-extend-train","phraseCount":4,"statsOverAll":{"id":"animals-extend-train-OverAll","tag":"OverAll","expectedCount":8,"observedCount":8,"truePositives":8,"falsePositives":0,"falseNegatives":0,"precision":1,"recall":1,"f1Score":1}},"testStatistics":{"id":"animals-extend-test","phraseCount":4,"statsOverAll":{"id":"animals-extend-test-OverAll","tag":"OverAll","expectedCount":8,"observedCount":8,"truePositives":8,"falsePositives":0,"falseNegatives":0,"precision":1,"recall":1,"f1Score":1},"statsPerEntity":[{"id":"animals-extend-test-Animal","tag":"Animal","expectedCount":4,"observedCount":4,"truePositives":4,"falsePositives":0,"falseNegatives":0,"precision":1,"recall":1,"f1Score":1},{"id":"animals-extend-test-Sound","tag":"Sound","expectedCount":4,"observedCount":4,"truePositives":4,"falsePositives":0,"falseNegatives":0,"precision":1,"recall":1,"f1Score":1}]},"labeledText":{"id":"animals","author":"wiki","sources":[{"id":"The cat says: meow-meow.","xText":"The <Animal>cat</Animal> says: <Sound>meow-meow</Sound>.","entityMentions":[{"tag":"Animal","token":"cat","span":3,"offset":4},{"tag":"Sound","token":"meow-meow","span":9,"offset":14}]},{"id":"The sheep says: baa-baa.","xText":"The <Animal>sheep</Animal> says: <Sound>baa-baa</Sound>.","entityMentions":[{"tag":"Animal","token":"sheep","span":5,"offset":4},{"tag":"Sound","token":"baa-baa","span":7,"offset":16}]},{"id":"The dog says: woof-woof.","xText":"The <Animal>dog</Animal> says: <Sound>woof-woof</Sound>.","entityMentions":[{"tag":"Animal","token":"dog","span":3,"offset":4},{"tag":"Sound","token":"woof-woof","span":9,"offset":14}]},{"id":"The horse says: neigh-neigh.","xText":"The <Animal>horse</Animal> says: <Sound>neigh-neigh</Sound>.","entityMentions":[{"tag":"Animal","token":"horse","span":5,"offset":4},{"tag":"Sound","token":"neigh-neigh","span":11,"offset":16}]},{"id":"The sparrow says: cheep-cheep.","xText":"The <Animal>sparrow</Animal> says: <Sound>cheep-cheep</Sound>.","entityMentions":[{"tag":"Animal","token":"sparrow","span":7,"offset":4},{"tag":"Sound","token":"cheep-cheep","span":11,"offset":18}]},{"id":"The rooster says: cock-a-doodle-doo.","xText":"The <Animal>rooster</Animal> says: <Sound>cock-a-doodle-doo</Sound>.","entityMentions":[{"tag":"Animal","token":"rooster","span":7,"offset":4},{"tag":"Sound","token":"cock-a-doodle-doo","span":17,"offset":18}]},{"id":"The hen says: cluck-cluck.","xText":"The <Animal>hen</Animal> says: <Sound>cluck-cluck</Sound>.","entityMentions":[{"tag":"Animal","token":"hen","span":3,"offset":4},{"tag":"Sound","token":"cluck-cluck","span":11,"offset":14}]},{"id":"The goose says: hhonk-honk.","xText":"The <Animal>goose</Animal> says: <Sound>hhonk-honk</Sound>.","entityMentions":[{"tag":"Animal","token":"goose","span":5,"offset":4},{"tag":"Sound","token":"hhonk-honk","span":10,"offset":16}]},{"id":"The turkey says: gobble-gobble.","xText":"The <Animal>turkey</Animal> says: <Sound>gobble-gobble</Sound>.","entityMentions":[{"tag":"Animal","token":"turkey","span":6,"offset":4},{"tag":"Sound","token":"gobble-gobble","span":13,"offset":17}]},{"id":"The goat says: maa-maa.","xText":"The <Animal>goat</Animal> says: <Sound>maa-maa</Sound>.","entityMentions":[{"tag":"Animal","token":"goat","span":4,"offset":4},{"tag":"Sound","token":"maa-maa","span":7,"offset":15}]},{"id":"The cow says: moo-moo.","xText":"The <Animal>cow</Animal> says: <Sound>moo-moo</Sound>.","entityMentions":[{"tag":"Animal","token":"cow","span":3,"offset":4},{"tag":"Sound","token":"moo-moo","span":7,"offset":14}]},{"id":"The donkey says: hee-haw.","xText":"The <Animal>donkey</Animal> says: <Sound>hee-haw</Sound>.","entityMentions":[{"tag":"Animal","token":"donkey","span":6,"offset":4},{"tag":"Sound","token":"hee-haw","span":7,"offset":17}]},{"id":"The pig says: oink-oink.","xText":"The <Animal>pig</Animal> says: <Sound>oink-oink</Sound>.","entityMentions":[{"tag":"Animal","token":"pig","span":3,"offset":4},{"tag":"Sound","token":"oink-oink","span":9,"offset":14}]},{"id":"The mouse says: squeak-squeak.","xText":"The <Animal>mouse</Animal> says: <Sound>squeak-squeak</Sound>.","entityMentions":[{"tag":"Animal","token":"mouse","span":5,"offset":4},{"tag":"Sound","token":"squeak-squeak","span":13,"offset":16}]},{"id":"The cuckoo says: cuckoo.","xText":"The <Animal>cuckoo</Animal> says: <Sound>cuckoo</Sound>.","entityMentions":[{"tag":"Animal","token":"cuckoo","span":6,"offset":4},{"tag":"Sound","token":"cuckoo","span":6,"offset":17}]},{"id":"The wolf says: owooooo.","xText":"The <Animal>wolf</Animal> says: <Sound>owooooo</Sound>.","entityMentions":[{"tag":"Animal","token":"wolf","span":4,"offset":4},{"tag":"Sound","token":"owooooo","span":7,"offset":15}]},{"id":"The pig says: oink-oink.","xText":"The <Animal>pig</Animal> says: <Sound>oink-oink</Sound>.","entityMentions":[{"tag":"Animal","token":"pig","span":3,"offset":4},{"tag":"Sound","token":"oink-oink","span":9,"offset":14}]},{"id":"The duck says: quack-quack.","xText":"The <Animal>duck</Animal> says: <Sound>quack-quack</Sound>.","entityMentions":[{"tag":"Animal","token":"duck","span":4,"offset":4},{"tag":"Sound","token":"quack-quack","span":11,"offset":15}]},{"id":"The frog says: ribbit-ribbit.","xText":"The <Animal>frog</Animal> says: <Sound>ribbit-ribbit</Sound>.","entityMentions":[{"tag":"Animal","token":"frog","span":4,"offset":4},{"tag":"Sound","token":"ribbit-ribbit","span":13,"offset":15}]},{"id":"The crow says: caw-caw.","xText":"The <Animal>crow</Animal> says: <Sound>caw-caw</Sound>.","entityMentions":[{"tag":"Animal","token":"crow","span":4,"offset":4},{"tag":"Sound","token":"caw-caw","span":7,"offset":15}]}]}}}}"""

# %%
print(len(str1))
print(len(str2))
# Out:
# 5746
# 5746

# %%
for i in range(len(str1)):
    if str1[i] != str2[i]:
        print("str1[{}] = ... {}".format(i, str1[i:i+10]))
        print("str2[{}] = ... {}".format(i, str2[i:i+10]))
        print()
# Out:
# str1[1508] = ... horse says
# str2[1508] = ... dog says:
#
# str1[1510] = ... rse says:
# str2[1510] = ... g says: wo
#
# str1[1511] = ... se says: n
# str2[1511] = ...  says: woo
#
# str1[1512] = ... e says: ne
# str2[1512] = ... says: woof
#
# str1[1513] = ...  says: nei
# str2[1513] = ... ays: woof-
#
# str1[1514] = ... says: neig
# str2[1514] = ... ys: woof-w
#
# str1[1515] = ... ays: neigh
# str2[1515] = ... s: woof-wo
#
# str1[1516] = ... ys: neigh-
# str2[1516] = ... : woof-woo
#
# str1[1517] = ... s: neigh-n
# str2[1517] = ...  woof-woof
#
# str1[1518] = ... : neigh-ne
# str2[1518] = ... woof-woof.
#
# str1[1519] = ...  neigh-nei
# str2[1519] = ... oof-woof."
#
# str1[1520] = ... neigh-neig
# str2[1520] = ... of-woof.",
#
# str1[1521] = ... eigh-neigh
# str2[1521] = ... f-woof.","
#
# str1[1522] = ... igh-neigh.
# str2[1522] = ... -woof.","x
#
# str1[1523] = ... gh-neigh."
# str2[1523] = ... woof.","xT
#
# str1[1524] = ... h-neigh.",
# str2[1524] = ... oof.","xTe
#
# ...
